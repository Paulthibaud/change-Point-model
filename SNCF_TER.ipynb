# %% [markdown]
# # Régularité mensuelle TER
#
# ## https://data.sncf.com/explore/dataset/regularite-mensuelle-ter/information/?disjunctive.region&sort=date

# %%
import pandas
fichier="regularite-mensuelle-ter.csv"

#df = pandas.read_csv(fichier,sep=";")
df=pandas.read_table(fichier,sep=";")
df.head(5)  #  afficher les 5 premières lignes
# Out:
#        ID     Date                      Région  Nombre de trains programmés  \
# 0   TER_2  2013-01                   Aquitaine                       8099.0
# 1   TER_4  2013-01             Basse Normandie                       3331.0
# 2   TER_5  2013-01                   Bourgogne                       8400.0
# 3  TER_19  2013-01  Provence Alpes Côte d'Azur                      13956.0
# 4  TER_20  2013-01                 Rhône Alpes                      31438.0
#
#    Nombre de trains ayant circulé  Nombre de trains annulés  \
# 0                          8014.0                      85.0
# 1                          3297.0                      34.0
# 2                          8332.0                      68.0
# 3                         13219.0                     737.0
# 4                         30779.0                     659.0
#
#    Nombre de trains en retard à l'arrivée  Taux de régularité  \
# 0                                   731.0                90.9
# 1                                   311.0                90.6
# 2                                   625.0                92.5
# 3                                  1816.0                86.3
# 4                                  3552.0                88.5
#
#    Nombre de trains à l'heure pour un train en retard à l'arrivée  \
# 0                                               10.0
# 1                                                9.6
# 2                                               12.3
# 3                                                6.3
# 4                                                7.7
#
#                                         Commentaires
# 0                Intempéries à partir du 20 janvier.
# 1  Grand froid et épisode neigeux les semaines 3 ...
# 2  Un mois de janvier qui surpasse les six exerci...
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ## noms des colonnes

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'Région', 'Nombre de trains programmés',
#        'Nombre de trains ayant circulé', 'Nombre de trains annulés',
#        'Nombre de trains en retard à l'arrivée', 'Taux de régularité',
#        'Nombre de trains à l'heure pour un train en retard à l'arrivée',
#        'Commentaires'],
#       dtype='object')

# %% [markdown]
# ## Ordonner les données par année

# %%
df1=df.sort_values(by=[df.columns[1]])
df1.head(10)
# Out:
#           ID     Date              Région  Nombre de trains programmés  \
# 0      TER_2  2013-01           Aquitaine                       8099.0
# 865    TER_1  2013-01              Alsace                      20095.0
# 866    TER_6  2013-01            Bretagne                       8776.0
# 867    TER_7  2013-01              Centre                       9882.0
# 868   TER_12  2013-01            Limousin                       3817.0
# 869   TER_15  2013-01  Nord Pas de Calais                      19227.0
# 596   TER_14  2013-01       Midi Pyrénées                       8208.0
# 597   TER_17  2013-01            Picardie                      11754.0
# 594    TER_3  2013-01            Auvergne                       5785.0
# 1152  TER_16  2013-01    Pays de la Loire                      10407.0
#
#       Nombre de trains ayant circulé  Nombre de trains annulés  \
# 0                             8014.0                      85.0
# 865                          19874.0                     221.0
# 866                           8631.0                     145.0
# 867                           9687.0                     195.0
# 868                           3770.0                      47.0
# 869                          18890.0                     337.0
# 596                           7941.0                     267.0
# 597                          11673.0                      81.0
# 594                           5732.0                      53.0
# 1152                         10195.0                     212.0
#
#       Nombre de trains en retard à l'arrivée  Taux de régularité  \
# 0                                      731.0                90.9
# 865                                    897.0                95.5
# 866                                    554.0                93.6
# 867                                    812.0                91.6
# 868                                    210.0                94.4
# 869                                   2332.0                87.7
# 596                                    903.0                88.6
# 597                                   1245.0                89.3
# 594                                    431.0                92.5
# 1152                                   713.0                93.0
#
#       Nombre de trains à l'heure pour un train en retard à l'arrivée  \
# 0                                                  10.0
# 865                                                21.2
# 866                                                14.6
# 867                                                10.9
# 868                                                17.0
# 869                                                 7.1
# 596                                                 7.8
# 597                                                 8.4
# 594                                                12.3
# 1152                                               13.3
#
#                                            Commentaires
# 0                   Intempéries à partir du 20 janvier.
# 865                                        Intempéries.
# 866   Fortes chutes de neige ayant entrainé des pert...
# 867   Trois incidents caténaires lourds, dont deux p...
# 868                                                 NaN
# 869                           Vol de câble à Lille Sud.
# 596                                                 NaN
# 597   Fortes chutes de neige ayant entrainé des pert...
# 594                     Conditions météos défavorables.
# 1152                                                NaN

# %% [markdown]
# ## Ordonner les données par années et Régions

# %%
df=df.sort_values(by=[df.columns[2],df.columns[1]])
df.head(10)
# Out:
#          ID     Date  Région  Nombre de trains programmés  \
# 865   TER_1  2013-01  Alsace                      20095.0
# 6     TER_1  2013-02  Alsace                      18263.0
# 288   TER_1  2013-03  Alsace                      19138.0
# 16    TER_1  2013-04  Alsace                      18846.0
# 613   TER_1  2013-05  Alsace                      18659.0
# 304   TER_1  2013-06  Alsace                      17810.0
# 309   TER_1  2013-07  Alsace                      14462.0
# 1176  TER_1  2013-08  Alsace                      15416.0
# 888   TER_1  2013-09  Alsace                      18800.0
# 1182  TER_1  2013-10  Alsace                      20430.0
#
#       Nombre de trains ayant circulé  Nombre de trains annulés  \
# 865                          19874.0                     221.0
# 6                            18097.0                     166.0
# 288                          18970.0                     168.0
# 16                           18726.0                     120.0
# 613                          18533.0                     126.0
# 304                          17668.0                     142.0
# 309                          14363.0                      99.0
# 1176                         15283.0                     133.0
# 888                          18680.0                     120.0
# 1182                         20274.0                     156.0
#
#       Nombre de trains en retard à l'arrivée  Taux de régularité  \
# 865                                    897.0                95.5
# 6                                      771.0                95.7
# 288                                    658.0                96.5
# 16                                     581.0                96.9
# 613                                    444.0                97.6
# 304                                    784.0                95.6
# 309                                    483.0                96.6
# 1176                                   418.0                97.3
# 888                                    801.0                95.7
# 1182                                  1032.0                94.9
#
#       Nombre de trains à l'heure pour un train en retard à l'arrivée  \
# 865                                                21.2
# 6                                                  22.5
# 288                                                27.8
# 16                                                 31.2
# 613                                                40.7
# 304                                                21.5
# 309                                                28.7
# 1176                                               35.6
# 888                                                22.3
# 1182                                               18.6
#
#                                            Commentaires
# 865                                        Intempéries.
# 6                                          Intempéries.
# 288                                                 NaN
# 16                                                  NaN
# 613                                                 NaN
# 304   Mouvement social et travaux à Vendenheim pour ...
# 309                                                 NaN
# 1176                                                NaN
# 888               Travaux Vendenheim 2ème phase TGV Est
# 1182  Travaux Vendenheim 2ème phase TGV Est et patin...

# %% [markdown]
# <h2> nombres d'occurences (Région)  </h2>
# <h2 style="color:red"> Pour le projet le modèle de détection de rupture sera appliqué à chaque région </h2>

# %% [markdown]
# ### 1. par dictionnaire

# %%
Dic={}  #  dictionnaire
# dic['clé']=valeur
# clé de dictionnaire = Nom de Gare (axe) 
# valeur de dictionnaire = nombre d'observations

for x in df[df.columns[2]].values:
    Dic[x]=list(df[df.columns[2]].values).count(x)

## ordonner le dictionnaire par les clés
#import collections 
#Dic=collections.OrderedDict(sorted(Dic.items(), key=lambda t: t[0]))
Dic
# Out:
# {'Alsace': 48,
#  'Aquitaine': 84,
#  'Auvergne': 60,
#  'Auvergne-Rhône Alpes': 24,
#  'Basse Normandie': 60,
#  'Bourgogne': 60,
#  'Bourgogne-Franche Comté': 24,
#  'Bretagne': 84,
#  'Centre': 84,
#  'Champagne Ardenne': 48,
#  'Franche Comté': 60,
#  'Grand Est': 36,
#  'Haute Normandie': 60,
#  'Hauts de France': 24,
#  'Languedoc Roussillon': 60,
#  'Limousin': 60,
#  'Lorraine': 48,
#  'Midi Pyrénées': 66,
#  'Nord Pas de Calais': 60,
#  'Normandie': 24,
#  'Occitanie': 18,
#  'Pays de la Loire': 84,
#  'Picardie': 60,
#  'Poitou Charentes': 60,
#  "Provence Alpes Côte d'Azur": 84,
#  'Rhône Alpes': 60}

# %% [markdown]
# ### 2. par le module pandas

# %%
df[df.columns[2]].value_counts()
# Out:
# Bretagne                      84
# Pays de la Loire              84
# Provence Alpes Côte d'Azur    84
# Aquitaine                     84
# Centre                        84
# Midi Pyrénées                 66
# Limousin                      60
# Picardie                      60
# Haute Normandie               60
# Bourgogne                     60
# Basse Normandie               60
# Franche Comté                 60
# Auvergne                      60
# Rhône Alpes                   60
# Poitou Charentes              60
# Languedoc Roussillon          60
# Nord Pas de Calais            60
# Alsace                        48
# Champagne Ardenne             48
# Lorraine                      48
# Grand Est                     36
# Bourgogne-Franche Comté       24
# Auvergne-Rhône Alpes          24
# Normandie                     24
# Hauts de France               24
# Occitanie                     18
# Name: Région, dtype: int64

# %%
# pour la région Aquitaine
df[df['Région']=='Aquitaine']
# Out:
#          ID     Date     Région  Nombre de trains programmés  \
# 0     TER_2  2013-01  Aquitaine                       8099.0
# 7     TER_2  2013-02  Aquitaine                       7926.0
# 1158  TER_2  2013-03  Aquitaine                       8167.0
# 609   TER_2  2013-04  Aquitaine                       8329.0
# 1163  TER_2  2013-05  Aquitaine                       8722.0
# ...     ...      ...        ...                          ...
# 857   TER_2  2019-08  Aquitaine                      16948.0
# 276   TER_2  2019-09  Aquitaine                      16344.0
# 1143  TER_2  2019-10  Aquitaine                      16366.0
# 587   TER_2  2019-11  Aquitaine                      15128.0
# 592   TER_2  2019-12  Aquitaine                       3888.0
#
#       Nombre de trains ayant circulé  Nombre de trains annulés  \
# 0                             8014.0                      85.0
# 7                             7832.0                      94.0
# 1158                          8081.0                      86.0
# 609                           8236.0                      93.0
# 1163                          8656.0                      66.0
# ...                              ...                       ...
# 857                          16705.0                     243.0
# 276                          16182.0                     162.0
# 1143                         14902.0                    1464.0
# 587                          14554.0                     574.0
# 592                           3635.0                     253.0
#
#       Nombre de trains en retard à l'arrivée  Taux de régularité  \
# 0                                      731.0                90.9
# 7                                      912.0                88.4
# 1158                                   822.0                89.8
# 609                                    967.0                88.3
# 1163                                   833.0                90.4
# ...                                      ...                 ...
# 857                                   1163.0                93.0
# 276                                   1067.0                93.4
# 1143                                  1256.0                91.6
# 587                                   1977.0                86.4
# 592                                    752.0                79.3
#
#       Nombre de trains à l'heure pour un train en retard à l'arrivée  \
# 0                                                  10.0
# 7                                                   7.6
# 1158                                                8.8
# 609                                                 7.5
# 1163                                                9.4
# ...                                                 ...
# 857                                                13.4
# 276                                                14.2
# 1143                                               10.9
# 587                                                 6.4
# 592                                                 3.8
#
#                                            Commentaires
# 0                   Intempéries à partir du 20 janvier.
# 7        Inondations au sud de Dax du 11 au 13 février.
# 1158  Coup de froid sur l'ensemble de la région lors...
# 609                        Cinq accidents de personnes.
# 1163  Deux actes de malveillance majeurs et cinq acc...
# ...                                                 ...
# 857                                                 NaN
# 276                                                 NaN
# 1143                                                NaN
# 587                                                 NaN
# 592                                                 NaN
#
# [84 rows x 10 columns]

# %% [markdown]
# ## graphique  (Nombre de trains programmés)

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt

Aquitaine=df[df['Région']=='Aquitaine']

fig = plt.figure(figsize=(10,7))
ax1 = fig.add_subplot(111)
# cacher les cadres : haut et droit
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

ax1.xaxis.set_ticks_position('bottom')

plt.plot([i for i in range(len(Aquitaine))],Aquitaine[Aquitaine.columns[3]].values)
ensemble_affichage=[i for i in range(len(Aquitaine)) if i%4==0]
plt.xticks(ensemble_affichage,[Aquitaine[Aquitaine.columns[1]].values[i] for i in ensemble_affichage],
           rotation=45,size=9)
plt.title("Aquitaine : {}".format(Aquitaine.columns[3]))
plt.show()

# %% [markdown]
# ## histogramme  (Nombre de trains programmés)

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
import numpy

Aquitaine=df[df['Région']=='Aquitaine']

print("Aquitaine : ",Aquitaine.columns[3])

fig = plt.figure(figsize=(10,7))
ax1 = fig.add_subplot(111)

# cacher les cadres : haut , droit et gauche
ax1.spines['right'].set_visible(False)
#ax1.spines['left'].set_visible(False)
ax1.spines['top'].set_visible(False)


ax1.xaxis.set_ticks_position('bottom')
#ax1.set_yticks([])

plt.hist(Aquitaine[Aquitaine.columns[3]].values , ec="white",color=numpy.random.rand(3))
plt.show()
# Out:
# Aquitaine :  Nombre de trains programmés

# %% [markdown]
# ## Nombre de trains ayant circulé

# %%
### Nombre de trains ayant circulé
# %matplotlib inline  
import matplotlib.pyplot as plt
import numpy

Aquitaine=df[df['Région']=='Aquitaine']

fig = plt.figure(figsize=(10,7))
ax1 = fig.add_subplot(111)
# cacher les cadres : haut et droit
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

ax1.xaxis.set_ticks_position('bottom')

plt.plot([i for i in range(len(Aquitaine))],Aquitaine[Aquitaine.columns[4]].values)
ensemble_affichage=[i for i in range(len(Aquitaine)) if i%4==0]
plt.xticks(ensemble_affichage,[Aquitaine[Aquitaine.columns[1]].values[i] for i in ensemble_affichage],
           rotation=45,size=9)
plt.title("Aquitaine : {}".format(Aquitaine.columns[4]))
plt.show()

# %% [markdown]
# ## Nombre de trains annulés

# %%
### Nombre de trains annulés
# %matplotlib inline  
import matplotlib.pyplot as plt
import numpy

Aquitaine=df[df['Région']=='Aquitaine']

print("Aquitaine : ",Aquitaine.columns[5])


fig = plt.figure(figsize=(10,7))
ax1 = fig.add_subplot(111)
# cacher les cadres : haut et droit
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

ax1.xaxis.set_ticks_position('bottom')

plt.plot([i for i in range(len(Aquitaine))],Aquitaine[Aquitaine.columns[5]].values)
ensemble_affichage=[i for i in range(len(Aquitaine)) if i%4==0]
plt.xticks(ensemble_affichage,[Aquitaine[Aquitaine.columns[1]].values[i] for i in ensemble_affichage],
           rotation=45,size=9)
#plt.title("Aquitaine")
plt.show()
# Out:
# Aquitaine :  Nombre de trains annulés

# %% [markdown]
# ## Nombre de trains en retard à l'arrivée

# %%
### Nombre de trains en retard à l'arrivée

# %matplotlib inline  
import matplotlib.pyplot as plt

Aquitaine=df[df['Région']=='Aquitaine']

print("Aquitaine : ",Aquitaine.columns[6])

fig = plt.figure(figsize=(10,7))
ax1 = fig.add_subplot(111)
# cacher les cadres : haut et droit
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

ax1.xaxis.set_ticks_position('bottom')

plt.plot([i for i in range(len(Aquitaine))],Aquitaine[Aquitaine.columns[6]].values)
ensemble_affichage=[i for i in range(len(Aquitaine)) if i%4==0]
plt.xticks(ensemble_affichage,[Aquitaine[Aquitaine.columns[1]].values[i] for i in ensemble_affichage],
           rotation=45,size=9)
#plt.title("Aquitaine")
plt.show()
# Out:
# Aquitaine :  Nombre de trains en retard à l'arrivée

# %%
def melange_gaussien(loi1,loi2,p1,p2):
    res = []
    for i in range(len(loi1)):
        res.append(p1*loi1[i]+p2*loi2[i])
    return res

# %%
import numpy as np

def normal(x, mu_, sigma_):
    return 1/np.sqrt(2*np.pi*sigma_**2) * np.exp(-1/2 * (x-mu_)**2/sigma_)

# %%
import numpy as np

def log_vraisemblance(data,mu1, mu2, sigma_,k):
    sums = -1/(2)*np.sum((data[:k] - mu1)**2) - 1/(2) * np.sum((data[k:] - mu2)**2)
    return sums

# %%
def rupture(X):
    logv_ = []
    sigma_ = np.var(X)
    n = len(X)
    for k in range(2,n-1):
        mu1 = np.mean(X[:k])
        mu2 = np.mean(X[k:])
        if ((mu1!=0) & (mu2 != 0)):
            log_ = log_vraisemblance(X,mu1,mu2,sigma_,k)
            logv_.append(log_)
    kmax = (numpy.where(logv_ == max(logv_))[0])[0]
    return [kmax,np.mean(X[:kmax]),np.mean(X[kmax:X.size]),sigma_]

# %%
data = df[df['Région']=='Aquitaine']['Nombre de trains ayant circulé']
print(np.min(data))
logv_ = []
print(np.var(data))
var = np.mean(abs(data - np.mean(data))**2)
print(var)
for k in range(2,len(data)-1):
    mu1 = np.mean(data[:k])
    mu2 = np.mean(data[k:])
    if ((mu1!=0) & (mu2 != 0)):
            x =0
            #logv_.append(log_vraisemblance(X,mu1,mu2,sigma_,k))
# Out:
# 3635.0
# 11987958.336167797
# 11987958.336167797

# %%
def Etat(gare,nom, colonne):
    rupt = rupture(gare[colonne].to_numpy())
    P1 = [normal(j,rupt[1],rupt[3]) for j in range(int(max(gare[colonne].values)+1))]
    P2 = [normal(j,rupt[2],rupt[3]) for j in range(int(max(gare[colonne].values)+1))]
    print(rupt)
    print(np.mean(gare[colonne].values))
    p1 = rupt[0]/len(gare[colonne].values)
    print(p1)
    p2 = 1 - p1
    
    print("k_rupture = ", rupt[0])
    print(nom, " : ", colonne)
    fig = plt.figure(figsize=(10,7))
    ax1 = fig.add_subplot(111)
    # cacher les cadres : haut et droit
    ax1.spines['right'].set_visible(False)
    ax1.spines['top'].set_visible(False)


    ax1.xaxis.set_ticks_position('bottom')

    l1 = [k for k in range(rupt[0])]
    l2 = [k for k in range(rupt[0],len(gare[colonne].values))]

    plt.plot(l1,gare[colonne].values[:rupt[0]], color = 'green')
    plt.plot(l2,gare[colonne].values[rupt[0]:], color = 'blue')
    plt.axvline(x=rupt[0],color='red')
    plt.show()

    print(nom, " : ", colonne)
    fig = plt.figure(figsize=(10,7))
    ax1 = fig.add_subplot(111)

    # cacher les cadres : haut , droit et gauche
    ax1.spines['right'].set_visible(False)
    #ax1.spines['left'].set_visible(False)
    ax1.spines['top'].set_visible(False)


    ax1.xaxis.set_ticks_position('bottom')
    #ax1.set_yticks([])

    plt.hist(gare[colonne].values,color=numpy.random.rand(3),density =True)
    plt.show()
    plt.plot(P1,color='g')
    plt.plot(P2,color='b')
    plt.plot(p1*np.array(P1)+p2*np.array(P2), color ='r')
    plt.show()

# %%
def etat_gare(gare,nom):
    gare_1=df[df['Région']=='Aquitaine']
    #gare_2=gare[gare[gare.columns[25]].notnull()]
    #gare_3=gare[gare[gare.columns[26]].notnull()]
    Etat(gare_1,nom,'Nombre de trains en retard à l\'arrivée')
    #Etat(gare_2,nom,'Nombre trains en retard > 30min')
    #Etat(gare_3,nom,'Nombre trains en retard > 60min')

# %%
etat_gare(df,"Aquitaine")
# Out:
# [57, 964.8947368421053, 1250.111111111111, 84133.07823129251]
# 1056.5714285714287
# 0.6785714285714286
# k_rupture =  57
# Aquitaine  :  Nombre de trains en retard à l'arrivée
# Aquitaine  :  Nombre de trains en retard à l'arrivée
